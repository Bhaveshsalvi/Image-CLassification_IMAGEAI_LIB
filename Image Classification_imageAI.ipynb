# %%
from imageai.Detection import ObjectDetection
import tensorflow as tf
# Out:
# Using TensorFlow backend.
# C:\Users\Bhavesh\Miniconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Bhavesh\Miniconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Bhavesh\Miniconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
import os

execution_path = os.getcwd()

# %% [markdown]
# ### RetinaNet Object detection

# %%
import os

execution_path = os.getcwd()

detector = ObjectDetection()
detector.setModelTypeAsRetinaNet()
detector.setModelPath( os.path.join(execution_path , "model/resnet50_coco_best_v2.0.1.h5"))
detector.loadModel()
# Out:
# tracking <tf.Variable 'Variable_5:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_6:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_7:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_8:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_9:0' shape=(9, 4) dtype=float32> anchors

# %%
custom_objects = detector.CustomObjects(person=True, car=False)

# %%
detections = detector.detectCustomObjectsFromImage(input_image=os.path.join(execution_path , "image3.jpg"), output_image_path=os.path.join(execution_path , "image3_new.jpg"), custom_objects=custom_objects, minimum_percentage_probability=65)

# %%
for eachObject in detections:
   print("{} equals to {}".format(eachObject["name"],eachObject["percentage_probability"]) )
   print("------------------------------")
# Out:
# person equals to 84.19637680053711
# ------------------------------
# person equals to 90.02483487129211
# ------------------------------
# person equals to 96.42556309700012
# ------------------------------

# %%
from IPython.display import Image
Image("image3_new.jpg")

# %% [markdown]
# ### RetinaNet

# %%
detector_retina = ObjectDetection()
detector_retina.setModelTypeAsRetinaNet()
detector_retina.setModelPath( os.path.join(execution_path , "model/resnet50_coco_best_v2.0.1.h5"))
detector_retina.loadModel()
# Out:
# tracking <tf.Variable 'Variable_10:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_11:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_12:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_13:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_14:0' shape=(9, 4) dtype=float32> anchors

# %%
detector_retina = detector_retina.detectObjectsFromImage(input_image="input_retinaNET/image3.jpg", output_image_path="output_retinaNET/image3.jpg")

# %%
for eachObject in detector_retina:
   print("{} equals to {}".format(eachObject["name"],eachObject["percentage_probability"]) )
   print("------------------------------")
# Out:
# person equals to 61.52569055557251
# ------------------------------
# person equals to 84.19637680053711
# ------------------------------
# dog equals to 56.43031597137451
# ------------------------------
# person equals to 90.02483487129211
# ------------------------------
# person equals to 96.42556309700012
# ------------------------------

# %%
from IPython.display import Image
Image("output_retinaNET/image3.jpg")

# %% [markdown]
# ### TinyYOLO

# %%
detectorTinyYolo = ObjectDetection()
detectorTinyYolo.setModelTypeAsTinyYOLOv3()
detectorTinyYolo.setModelPath( os.path.join(execution_path , "model/yolo-tiny.h5"))
detectorTinyYolo.loadModel()

# %%
detectorTinyYolo = detectorTinyYolo.detectObjectsFromImage(input_image="input_tinyYOLO/image3.jpg", output_image_path="output_YOLO3/image3.jpg")

# %%
for eachObject in detectorTinyYolo:
   print("{} equals to {}".format(eachObject["name"],eachObject["percentage_probability"]) )
   print("------------------------------")
# Out:
# umbrella equals to 53.182464838027954
# ------------------------------
# umbrella equals to 82.07589983940125
# ------------------------------
# motorcycle equals to 76.67772173881531
# ------------------------------
# motorcycle equals to 85.63585877418518
# ------------------------------
# car equals to 55.21215200424194
# ------------------------------
# car equals to 55.29600977897644
# ------------------------------
# car equals to 58.00100564956665
# ------------------------------
# car equals to 66.30896925926208
# ------------------------------
# car equals to 83.37965607643127
# ------------------------------
# car equals to 85.60402393341064
# ------------------------------
# person equals to 60.959553718566895
# ------------------------------
# person equals to 79.446941614151
# ------------------------------
# person equals to 86.9823157787323
# ------------------------------

# %%
from IPython.display import Image
Image("output_tinyYOLO/image3.jpg")

# %% [markdown]
# ### YOLO3

# %%
detectorYOLO3 = ObjectDetection()
detectorYOLO3.setModelTypeAsYOLOv3()
detectorYOLO3.setModelPath( os.path.join(execution_path , "model/model.h5"))
detectorYOLO3.loadModel()

# %%
detectorYOLO3 = detectorYOLO3.detectObjectsFromImage(input_image="input_YOLO3/image3.jpg", output_image_path="output_YOLO3/image3.jpg")

# %%
for eachObject in detectorYOLO3:
   print("{} equals to {}".format(eachObject["name"],eachObject["percentage_probability"]) )
   print("------------------------------")
# Out:
# umbrella equals to 53.182464838027954
# ------------------------------
# umbrella equals to 82.07589983940125
# ------------------------------
# motorcycle equals to 76.67772173881531
# ------------------------------
# motorcycle equals to 85.63585877418518
# ------------------------------
# car equals to 55.21215200424194
# ------------------------------
# car equals to 55.29600977897644
# ------------------------------
# car equals to 58.00100564956665
# ------------------------------
# car equals to 66.30896925926208
# ------------------------------
# car equals to 83.37965607643127
# ------------------------------
# car equals to 85.60402393341064
# ------------------------------
# person equals to 60.959553718566895
# ------------------------------
# person equals to 79.446941614151
# ------------------------------
# person equals to 86.9823157787323
# ------------------------------

# %%
from IPython.display import Image
Image("output_YOLO3/image3.jpg")
